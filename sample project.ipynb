# %%
import pandas as pd
import numpy as np
d1=pd.read_csv("C:\idtech\python\ML\sample project\country_wise_latest.csv")
d2=pd.read_csv(r"C:\idtech\python\ML\sample project\covid_19_clean_complete.csv")
d3=pd.read_csv(r"C:\idtech\python\ML\sample project\day_wise.csv")
d4=pd.read_csv(r"C:\idtech\python\ML\sample project\full_grouped.csv")
d5=pd.read_csv(r"C:\idtech\python\ML\sample project\usa_county_wise.csv")
d6=pd.read_csv("C:\idtech\python\ML\sample project\worldometer_data.csv")
d1.head(2)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
d2.head(1)
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean

# %%
d3.head(1)
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6

# %%
d4.head(1)
# Out:
#          Date Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0  2020-01-22    Afghanistan          0       0          0       0          0
#
#    New deaths  New recovered             WHO Region
# 0           0              0  Eastern Mediterranean

# %%
d5.head(1)
# Out:
#    UID iso2 iso3  code3  FIPS Admin2  Province_State Country_Region     Lat  \
# 0   16   AS  ASM     16  60.0    NaN  American Samoa             US -14.271
#
#      Long_        Combined_Key     Date  Confirmed  Deaths
# 0 -170.132  American Samoa, US  1/22/20          0       0

# %%
d6.head(1)
# Out:
#   Country/Region      Continent   Population  TotalCases  NewCases  \
# 0            USA  North America  331198130.0     5032179       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
#
#    Tests/1M pop WHO Region
# 0      190640.0   Americas

# %%
data=pd.concat([d1,d2,d3,d4,d5,d6],axis=1)
data
# Out:
#        Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0         Afghanistan    36263.0  1269.0    25198.0  9796.0      106.0
# 1             Albania     4880.0   144.0     2745.0  1991.0      117.0
# 2             Algeria    27973.0  1163.0    18837.0  7973.0      616.0
# 3             Andorra      907.0    52.0      803.0    52.0       10.0
# 4              Angola      950.0    41.0      242.0   667.0       18.0
# ...               ...        ...     ...        ...     ...        ...
# 627915            NaN        NaN     NaN        NaN     NaN        NaN
# 627916            NaN        NaN     NaN        NaN     NaN        NaN
# 627917            NaN        NaN     NaN        NaN     NaN        NaN
# 627918            NaN        NaN     NaN        NaN     NaN        NaN
# 627919            NaN        NaN     NaN        NaN     NaN        NaN
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627920 entries, 0 to 627919
# Data columns (total 77 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Country/Region          187 non-null     object
#  1   Confirmed               187 non-null     float64
#  2   Deaths                  187 non-null     float64
#  3   Recovered               187 non-null     float64
#  4   Active                  187 non-null     float64
#  5   New cases               187 non-null     float64
#  6   New deaths              187 non-null     float64
#  7   New recovered           187 non-null     float64
#  8   Deaths / 100 Cases      187 non-null     float64
#  9   Recovered / 100 Cases   187 non-null     float64
#  10  Deaths / 100 Recovered  187 non-null     float64
#  11  Confirmed last week     187 non-null     float64
#  12  1 week change           187 non-null     float64
# ...

# %%
data.isna().any()
# Out:
# Country/Region      True
# Confirmed           True
# Deaths              True
# Recovered           True
# Active              True
#                     ...
# Tot Cases/1M pop    True
# Deaths/1M pop       True
# TotalTests          True
# Tests/1M pop        True
# WHO Region          True
# Length: 77, dtype: bool

# %%
data.isnull().sum()
# Out:
# Country/Region      627733
# Confirmed           627733
# Deaths              627733
# Recovered           627733
# Active              627733
#                      ...
# Tot Cases/1M pop    627712
# Deaths/1M pop       627733
# TotalTests          627729
# Tests/1M pop        627729
# WHO Region          627736
# Length: 77, dtype: int64

# %%
data.fillna(method='bfill',inplace=True)

# %%
data.fillna(method='ffill',inplace=True)

# %%
data.isna().any()
# Out:
# Country/Region      False
# Confirmed           False
# Deaths              False
# Recovered           False
# Active              False
#                     ...
# Tot Cases/1M pop    False
# Deaths/1M pop       False
# TotalTests          False
# Tests/1M pop        False
# WHO Region          False
# Length: 77, dtype: bool

# %%
duplicate_cols = data.columns[data.columns.duplicated()]
data.drop(columns=duplicate_cols, inplace=True)

# %%
data.columns
# Out:
# Index(['Confirmed last week', '1 week change', '1 week % increase',
#        'Province/State', 'Long', 'No. of countries', 'UID', 'iso2', 'iso3',
#        'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Long_',
#        'Combined_Key', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627920 entries, 0 to 627919
# Data columns (total 30 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Confirmed last week  627920 non-null  float64
#  1   1 week change        627920 non-null  float64
#  2   1 week % increase    627920 non-null  float64
#  3   Province/State       627920 non-null  object
#  4   Long                 627920 non-null  float64
#  5   No. of countries     627920 non-null  float64
#  6   UID                  627920 non-null  int64
#  7   iso2                 627920 non-null  object
#  8   iso3                 627920 non-null  object
#  9   code3                627920 non-null  int64
#  10  FIPS                 627920 non-null  float64
#  11  Admin2               627920 non-null  object
#  12  Province_State       627920 non-null  object
#  13  Country_Region       627920 non-null  object
# ...

# %%
data.head(10)
# Out:
#    Confirmed last week  1 week change  1 week % increase  \
# 0              35526.0          737.0               2.07
# 1               4171.0          709.0              17.00
# 2              23691.0         4282.0              18.07
# 3                884.0           23.0               2.60
# 4                749.0          201.0              26.84
# 5                 76.0           10.0              13.16
# 6             130774.0        36642.0              28.02
# 7              34981.0         2409.0               6.89
# 8              12428.0         2875.0              23.13
# 9              19743.0          815.0               4.13
#
#                  Province/State        Long  No. of countries       UID iso2  \
# 0  Australian Capital Territory   67.709953               6.0        16   AS
# 1  Australian Capital Territory   20.168300               8.0       316   GU
# 2  Australian Capital Territory    1.659600               9.0       580   MP
# ...

# %%
# data.isna().any()

# %%
# data.info()

# %%
# data.fillna(method="ffill",inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in data.columns:
    data[i]=le.fit_transform(data[i])

# %%
data=data[['NewCases', 'TotalDeaths','TotalRecovered','Population', 'TotalCases', 
       'NewDeaths',  'NewRecovered',
       'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
       'TotalTests','Confirmed last week', '1 week change', '1 week % increase',
       'Province/State', 'Long', 'No. of countries', 'UID', 'iso2', 'iso3',
       'code3', 'FIPS', 'Admin2', 'Province_State', 'Country_Region', 'Long_',
       'Combined_Key', 'Continent', 'Tests/1M pop']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18492/2500794497.py in <module>
# ----> 1 data=data[['NewCases', 'TotalDeaths','TotalRecovered','Population', 'TotalCases',
#       2        'NewDeaths',  'NewRecovered',
#       3        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#       4        'TotalTests','Confirmed last week', '1 week change', '1 week % increase',
#       5        'Province/State', 'Long', 'No. of amal', 'UID', 'iso2', 'iso3',
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ...

# %%
data.head(2)
# Out:
#    NewCases  TotalDeaths  TotalRecovered  Population  TotalCases  NewDeaths  \
# 0         3          149             200         206         205          2
# 1         3          148             199         203         204          2
#
#    NewRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  ...  iso3  \
# 0             2          179                73               193  ...     0
# 1             2          178                71               190  ...     1
#
#    code3  FIPS  Admin2  Province_State  Country_Region  Long_  Combined_Key  \
# 0      0     0       7               2               0      1            61
# 1      1     1       7              14               0   3224          1175
#
#    Continent  Tests/1M pop
# 0          4           172
# 1          5           128
#
# [2 rows x 30 columns]

# %%
x=data.iloc[:,3:12]
x.head(5)
# Out:
#    Population  TotalCases  NewDeaths  NewRecovered  ActiveCases  \
# 0         206         205          2             2          179
# 1         203         204          2             2          178
# 2         207         203          2             2          177
# 3         200         202          2             2          176
# 4         184         201          2             2          174
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests
# 0                73               193             97         189
# 1                71               190             96         185
# 2                72               110             32         187
# 3                68               171             63         188
# 4                58               184             75         175

# %%
y=data.iloc[:,0:3]
y.head(1)
# Out:
#    NewCases  TotalDeaths  TotalRecovered
# 0         3          149             200

# %%
data[data.columns[0:]].corr()['NewCases'][:]
# Out:
# NewCases               1.000000
# TotalDeaths            0.050353
# TotalRecovered        -0.009401
# Population             0.079203
# TotalCases            -0.002694
# NewDeaths              0.718691
# NewRecovered           0.718691
# ActiveCases           -0.006429
# Serious,Critical       0.198694
# Tot Cases/1M pop      -0.020586
# Deaths/1M pop          0.075353
# TotalTests             0.001447
# Confirmed last week   -0.061936
# 1 week change          0.040928
# 1 week % increase      0.123258
# Province/State        -0.001923
# Long                  -0.004357
# No. of countries      -0.229566
# UID                    0.001812
# iso2                  -0.002385
# iso3                  -0.002385
# code3                 -0.002385
# FIPS                  -0.004666
# Admin2                -0.008367
# Province_State        -0.002278
# Country_Region              NaN
# Long_                 -0.002733
# Combined_Key          -0.007429
# Continent              0.016692
# ...

# %%
data[data.columns[0:]].corr()['TotalDeaths'][:]
# Out:
# NewCases               0.050353
# TotalDeaths            1.000000
# TotalRecovered         0.959459
# Population             0.859466
# TotalCases             0.964268
# NewDeaths              0.640843
# NewRecovered           0.640843
# ActiveCases            0.954691
# Serious,Critical       0.879091
# Tot Cases/1M pop       0.812601
# Deaths/1M pop          0.762969
# TotalTests             0.909128
# Confirmed last week    0.396993
# 1 week change         -0.260821
# 1 week % increase     -0.679132
# Province/State        -0.038588
# Long                   0.003320
# No. of countries      -0.874351
# UID                   -0.023355
# iso2                  -0.060315
# iso3                  -0.060315
# code3                 -0.060315
# FIPS                   0.008140
# Admin2                -0.006384
# Province_State         0.000788
# Country_Region              NaN
# Long_                  0.015906
# Combined_Key          -0.005467
# Continent              0.630092
# ...

# %%
data[data.columns[0:]].corr()['TotalRecovered'][:]
# Out:
# NewCases              -0.009401
# TotalDeaths            0.959459
# TotalRecovered         1.000000
# Population             0.860481
# TotalCases             0.996746
# NewDeaths              0.572357
# NewRecovered           0.572357
# ActiveCases            0.966719
# Serious,Critical       0.849809
# Tot Cases/1M pop       0.874150
# Deaths/1M pop          0.745783
# TotalTests             0.950773
# Confirmed last week    0.443217
# 1 week change         -0.288080
# 1 week % increase     -0.763705
# Province/State        -0.044698
# Long                  -0.000457
# No. of countries      -0.822968
# UID                   -0.026029
# iso2                  -0.057251
# iso3                  -0.057251
# code3                 -0.057251
# FIPS                   0.004430
# Admin2                -0.005867
# Province_State        -0.003273
# Country_Region              NaN
# Long_                  0.014727
# Combined_Key          -0.005022
# Continent              0.654819
# ...

# %%
from sklearn.model_selection import train_test_split
trainx,testx,trainy,testy=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
trainx
# Out:
#         Population  TotalCases  NewDeaths  NewRecovered  ActiveCases  \
# 250063          43           0          0             0            1
# 174103          43           0          0             0            1
# 278020          43           0          0             0            1
# 233222          43           0          0             0            1
# 29947           43           0          0             0            1
# ...            ...         ...        ...           ...          ...
# 359783          43           0          0             0            1
# 152315          43           0          0             0            1
# 117952          43           0          0             0            1
# 435829          43           0          0             0            1
# 305711          43           0          0             0            1
#
#         Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests
# ...

# %%
from sklearn.preprocessing import StandardScaler
sd=StandardScaler()
trainx=sd.fit_transform(trainx)
# trainy=sd.fit(trainy)
testx=sd.fit_transform(testx)

# %%
import seaborn as sns
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(trainx,trainy)
pred=model.predict(testx)

# %%
pred
# Out:
# array([[ 1.00003358, -0.00263756,  0.99621291],
#        [ 1.00003358, -0.00263756,  0.99621291],
#        [ 1.00003358, -0.00263756,  0.99621291],
#        ...,
#        [ 1.00003358, -0.00263756,  0.99621291],
#        [ 1.00003358, -0.00263756,  0.99621291],
#        [ 1.00003358, -0.00263756,  0.99621291]])

# %%
from sklearn.metrics import mean_squared_error as mse
m=mse(pred,testy)
m
# Out:
# 0.03687357806622782

# %%
from sklearn.metrics import r2_score
r=r2_score(pred,testy)
r
# Out:
# 0.9046538523773617

# %%
x.head(2)
# data.shape
# Out:
#    Population  TotalCases  NewDeaths  NewRecovered  ActiveCases  \
# 0         206         205          2             2          179
# 1         203         204          2             2          178
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests
# 0                73               193             97         189
# 1                71               190             96         185

# %%
result=model.predict([[206,205,2,2,179,73,193,97,189]])
result
# Out:
# array([[-9.08932969e-02,  2.21107321e+02,  4.41641568e+02]])

# %%
import matplotlib.pyplot as plt
b1=pd.DataFrame({'Ac':[0.9310505138690838],'mse':[0.029128546572247272]})
Ac=b1['Ac'].tolist()
mse=b1['mse'].tolist()
plt.plot(Ac, mse, label = 'covid 19 data of last year',color='black', marker='o', markerfacecolor='green',linestyle='--', linewidth=3)

plt.xlabel('Accuracy')
plt.ylabel('Mean square error')
# plt.pie/(b1)
plt.show()
